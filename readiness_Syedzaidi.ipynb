# %%
import sys
print(sys.executable)
# Out:
# C:\Users\Humzah\anaconda3\python.exe

# %%
def get_mean_and_max(numbers):
    """Take a list of numbers and return a tuple of (mean,maximum)."""
    mean = sum(numbers) / len(numbers)
    maximum = max(numbers)
    return mean, maximum

sample_numbers = [4, 8, 15, 16, 23, 42]
mean, maximum = get_mean_and_max(sample_numbers)

print(f"Numbers: {sample_numbers}")
print(f"Mean: {mean}")
print(f"Maximum: {maximum}")
# Out:
# Numbers: [4, 8, 15, 16, 23, 42]
# Mean: 18.0
# Maximum: 42

# %% [markdown]
# A difference I noticed when working between VS Code and Jupyter is that Jupyter does not have a separate terminal. When you run the code the output is displayed right underneath the cell. VS Code also runs the whole script at once, while Jupyter runs cell by cell.
